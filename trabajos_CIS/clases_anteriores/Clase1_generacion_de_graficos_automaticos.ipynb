# %% [markdown]
# <a href="https://colab.research.google.com/github/nrubio6131/nico_CIS/blob/master/trabajos_CIS/Clase1_generacion_de_graficos_automaticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabajo 1
# * Primero se importan las librerias principales

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#para dar un poco de formato a las imagenes del jupyter, centra los plot
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: center;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: center;
# }
# </style>

# %%
plt.rcParams['figure.figsize'] = [15, 20]# apra aumentar la iamgen den la visualización de jupyter

# %% [markdown]
# * Función que genera en cada casion un a serie de puntos aleatorios
# * Funcion que realiza las gráficas

# %%
def valores():
    df=pd.DataFrame(
        {'x': range(1,21),
         'y': np.random.randn(20), 
         'z': np.random.randn(20)
         })
    return(df)

def dibujar(graf):
    plt.rcParams['figure.figsize'] = [7, len(graf)*2]# apra aumentar la iamgen den la visualización de jupyter
    if len(graf) == 1:
        plt.plot(graf[0].x,graf[0].y)
    else:
        fig, axs = plt.subplots( len(graf), 1)
        for x in range(len(graf)):
            axs[x].grid(True);
            axs[x].plot(graf[x].x,graf[x].y);
            axs[x].set_ylabel('varaible en y{}'.format(x+1))  
    plt.xlabel('variable en x')  
    plt.show()

# %%
graf=[valores(),valores(),valores(),valores(),valores()]
dibujar(graf)

# %% [markdown]
# ## Otra forma para implementarlo

# %%
def valores():
  df=pd.DataFrame(
    {'x': range(1,21),
     'y': np.random.randn(20), 
     'z': np.random.randn(20)
     })
  return(df)

def dibujar2(graf,filas,colum):
    plt.rcParams['figure.figsize'] = [colum*4, filas*2]# apra aumentar la iamgen den la visualización de jupyter
    z=0;
    if filas*colum == len(graf):
        fig, axs = plt.subplots( filas, colum)
        for x in range(filas):
            for y in range(colum):
                axs[x,y].grid(True);
                axs[x,y].plot(graf[z].x,graf[z].y);
                axs[x,y].set_ylabel('varaible en y{}'.format(z+1)) 
                z+=1 
            axs[x,y].set_xlabel('variable en x')  
        plt.show()
    else:
        print('el tamaño no es el adecuado')

# %%
graf=[valores(),valores(),valores(),valores(),valores(),valores()]
dibujar2(graf,3,2)
