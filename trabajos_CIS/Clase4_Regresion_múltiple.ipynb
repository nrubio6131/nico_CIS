# %% [markdown]
# <a href="https://colab.research.google.com/github/nrubio6131/nico_CIS/blob/master/trabajos_CIS/Clase4_Regresion_múltiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_boston#.load_boston()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#importamos los datos
dfx = pd.DataFrame(load_boston().data, columns=(load_boston()).feature_names)
dfy = pd.DataFrame(load_boston().target)

# %%
#Organizamos los datos
X=dfx.iloc[:,:]
X=X.to_numpy()
Y= dfy.iloc[:,0]
Y = Y[:, np.newaxis]
print("Dimensiones en X: {}".format(str(X.shape)))
print("Dimension en Y: {}".format(str(Y.shape)))
# Out:
# Dimensiones en X: (506, 13)
# Dimension en Y: (506, 1)

# %%
plt.rcParams['figure.figsize'] = [15, 4]# para aumentar la iamgen den la visualización de jupyter
f, [ax1, ax2, ax3] = plt.subplots(1, 3, sharey=True) 
ax1.scatter(X[:,0],Y)
ax1.set_xlabel("habitaciones por vivienda");ax1.set_ylabel("precio viviendas")
ax2.scatter(X[:,1],Y)
ax2.set_xlabel("edad media viviendas")
ax3.scatter(X[:,2],Y)
ax3.set_xlabel("distancia ponderadas a centros de trabajo ")
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=.3, random_state=4)

# %%
regresion_multiple = LinearRegression()
regresion_multiple.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred= regresion_multiple.predict(X_test)
print('resultado del entrenamiento = {}'.format(regresion_multiple.score(X_train,Y_train)))
print('resultado con los datos de prueba = {}'.format(regresion_multiple.score(X_test,Y_test)))
# Out:
# resultado del entrenamiento = 0.7465991966746854
# resultado con los datos de prueba = 0.7121818377409184

# %%
print('coeficientes : a = {}, b = {}'.format(regresion_multiple.coef_[0,:],regresion_multiple.intercept_))
# Out:
# coeficientes : a = [-1.22569795e-01  5.56776996e-02 -8.83428230e-03  4.69344849e+00
#  -1.44357828e+01  3.28008033e+00 -3.44778157e-03 -1.55214419e+00
#   3.26249618e-01 -1.40665500e-02 -8.03274915e-01  9.35368715e-03
#  -5.23477529e-01], b = [36.35704138]
