# %% [markdown]
# <a href="https://colab.research.google.com/github/nrubio6131/nico_CIS/blob/master/carpeta/Tarea1nueva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabajo 1
# * Primero se importan las librerias principales

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize'] = [15, 15]# apra aumentar la iamgen den la visualización de jupyter

# %% [markdown]
# * Función que genera en cada casion un a serie de puntos aleatorios
# * Funcion que realiza las gráficas

# %%
def valores():
  df=pd.DataFrame(
    {'x': range(1,21),
     'y': np.random.randn(20), 
     'z': np.random.randn(20)
     })
  return(df)

def dibujar(graf,filas,colum):
  z=0;
  if filas*colum == len(graf):
    fig, axs = plt.subplots( filas, colum)
    for x in range(filas):
      for y in range(colum):
        axs[x,y].grid(True);
        axs[x,y].plot(graf[z].x,graf[z].y);
        axs[x,y].set_ylabel('varaible en y{}'.format(z+1)) 
        z+=1 
    plt.xlabel('variable en x')  
    plt.show()
  else:
    print('el tamaño no es el adecuado')

# %%
graf=[valores(),valores(),valores(),valores(),valores(),valores()]
dibujar(graf,2,3)
